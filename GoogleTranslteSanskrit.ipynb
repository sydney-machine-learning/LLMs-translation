# %%
from googletrans import Translator
import pandas as pd
import requests
from bs4 import BeautifulSoup

def get_sanskrit_sloka(url):
    page_request = requests.get(url)
    if page_request.status_code == 200:
        data = page_request.content
        soup = BeautifulSoup(data, "html.parser")
        sloka_text = soup.find('div', class_='r r-devanagari').text
        return sloka_text
    else:
        print(f"Failed to retrieve sloka from {url}")
        return None

def translate_slokas(df):
    translator = Translator()
    df['slokas_google'] = df['slokas'].apply(lambda x: translator.translate(x, dest='en').text)

def get_chapter_slokas(chapter, sloka_numbers):
    slokas = {}
    base_url = "https://vedabase.io/en/library/bg/"

    for sloka_number in sloka_numbers:
        sloka_url = f"{base_url}{chapter}/{sloka_number}/"
        sloka_text = get_sanskrit_sloka(sloka_url)

        if sloka_text is not None:
            slokas[sloka_number] = sloka_text

    return slokas

# List of grouped slokas for Chapter 1
list_slokas_chap1 = [str(x) for x in range(1, 16)]
list_slokas_chap1.extend(['16-18'])
list_slokas_chap1.extend([str(x) for x in range(19, 21)])
list_slokas_chap1.extend(['21-22'])
list_slokas_chap1.extend([str(x) for x in range(23, 32)])
list_slokas_chap1.extend(['32-35', '36', '37-38'])
list_slokas_chap1.extend([str(x) for x in range(39, 47)])

# Get the slokas for Chapter 1
sloks_chap1 = get_chapter_slokas(1, list_slokas_chap1)

# Create a DataFrame from the retrieved slokas and add a "chapter_no" column
slokas_df = pd.DataFrame({'chapter_no': 1, 'slokas_no': list(sloks_chap1.keys()), 'slokas': list(sloks_chap1.values())})

translate_slokas(slokas_df)

# Display the DataFrame
print(slokas_df)
# Out:
#     chapter_no slokas_no                                             slokas  \
# 0            1         1  धृतराष्ट्र उवाचधर्मक्षेत्रे कुरुक्षेत्रे समवेत...
# 1            1         2  सञ्जय उवाचदृष्ट्वा तु पाण्डवानीकं व्यूढं दुर्य...
# 2            1         3  पश्यैतां पाण्डुपुत्राणामाचार्य महतीं चमूम् ।व्...
# 3            1         4  अत्र श‍ूरा महेष्वासा भीमार्जुनसमा युधि ।युयुधा...
# 4            1         5  धृष्टकेतुश्चेकितानः काशिराजश्च वीर्यवान् ।पुरु...
# 5            1         6  युधामन्युश्च विक्रान्त उत्तमौजाश्च वीर्यवान् ।...
# 6            1         7  अस्माकं तु विशिष्टा ये तान्निबोध द्विजोत्तम ।न...
# 7            1         8  भवान्भीष्मश्च कर्णश्च कृपश्च समितिंजयः ।अश्वत्...
# 8            1         9  अन्ये च बहवः श‍ूरा मदर्थे त्यक्तजीविताः ।नानाश...
# 9            1        10  अपर्याप्त‍ं तदस्माकं बलं भीष्माभिरक्षितम् ।पर्...
# 10           1        11  अयनेषु च सर्वेषु यथाभागवमस्थिताः ।भीष्ममेवाभिर...
# 11           1        12  तस्य सञ्जनयन्हर्षं कुरुवृद्धः पितामहः ।सिंहनाद...
# 12           1        13  ततः शङ्खाश्च भेर्यश्च पणवानकगोमुखाः ।सहसैवाभ्य...
# 13           1        14  ततः श्वेतैर्हयैर्युक्ते महति स्यन्दने स्थितौ ।...
# 14           1        15  पाञ्चजन्यं हृषीकेशो देवदत्तं धनञ्जयः ।पौण्ड्रं...
# 15           1     16-18  अनन्तविजयं राजा कुन्तीपुत्रो युधिष्ठिरः ।नकुलः...
# 16           1        19  स घोषो धार्तराष्ट्राणां हृदयानि व्यदारयत् ।नभश...
# 17           1        20  अथ व्यवस्थितान्दृष्ट्वा धार्तराष्ट्रान्कपिध्वज...
# 18           1     21-22  अर्जुन उवाचसेनयोरुभयोर्मध्ये रथं स्थापय मेऽच्य...
# 19           1        23  योत्स्यमानानवेक्षेऽहं य एतेऽत्र समागताः ।धार्त...
# 20           1        24  सञ्जय उवाचएवमुक्तो हृषीकेशो गुडाकेशेन भारत ।से...
# 21           1        25  भीष्मद्रोणप्रमुखतः सर्वेषां च महीक्षिताम्  ।उव...
# 22           1        26  तत्रापश्यत्स्थितान्पार्थः पितॄनथ पितामहान्।आचा...
# 23           1        27  तान्समीक्ष्य स कौन्तेयः सर्वान्बन्धूनवस्थितान्...
# 24           1        28  अर्जुन उवाचदृष्ट्वेमं स्वजनं कृष्ण युयुत्सुं स...
# 25           1        29  वेपथुश्च शरीरे मे रोमहर्षश्च जायते ।गाण्डीवं स...
# 26           1        30  न च शक्न‍ोम्यवस्थातुं भ्रमतीव च मे मनः ।निमित्...
# 27           1        31  न च श्रेयोऽनुपश्यामि हत्वा स्वजनमाहवे ।न काङ्क...
# 28           1     32-35  किं नो राज्येन गोविन्द किं भोगैर्जीवितेन वा ।य...
# 29           1        36  पापमेवाश्रयेदस्मान्हत्वैतानाततायिनः ।तस्मान्ना...
# 30           1     37-38  यद्यप्येते न पश्यन्ति लोभोपहतचेतसः ।कुलक्षयकृत...
# 31           1        39  कुलक्षये प्रणश्यन्ति कुलधर्माः सनातनाः ।धर्मे ...
# 32           1        40  अधर्माभिभवात्कृष्ण प्रदुष्यन्ति कुलस्त्रियः ।स...
# 33           1        41  सङ्करो नरकायैव कुलघ्न‍ानां कुलस्य च ।पतन्ति पि...
# 34           1        42  दोषैरेतैः कुलघ्न‍ानां वर्णसङ्करकारकैः ।उत्साद्...
# 35           1        43  उत्सन्नकुलधर्माणां मनुष्याणां जनार्दन ।नरके नि...
# 36           1        44  अहो बत महत्पापं कर्तुं व्यवसिता वयम् ।यद्राज्य...
# 37           1        45  यदि मामप्रतीकारमशस्त्रं शस्त्रपाणयः ।धार्तराष्...
# 38           1        46  सञ्जय उवाचएवमुक्त्वार्जुनः संख्ये रथोपस्थ उपाव...
#
#                                         slokas_google
# 0   Dhṛtarāṣṭra said: O Sanjaya, what did the Pāṇḍ...
# 1   Sanjaya saw the army of the Pāṇḍavas arranged ...
# 2   O teacher look at this great army of the sons ...
# 3   Here the great archer Bhīma and Arjuna are equ...
# 4   Dhrishtaketu Chekitana the mighty king of Kāśī...
# 5   Yudhamanyu and Vikranta Uttamauja were the mig...
# 6   O best of the brāhmaṇas listen to those who ar...
# 7   You are Bhishma Karna Kripa Samitinjaya Ashvat...
# 8   Many other brave men gave up their lives for M...
# 9   The strength of ours is protected by Bhīma and...
# 10  May all of you, who are situated in all the ay...
# 11  The mighty grandfather of the Kurus shook the ...
# 12  Then suddenly the sounds of the conches and th...
# 13  Then the two divine conchshells, Mādhava and t...
# 14  The son of Pāñcājanya and the son of Hṛṣīkeśa,...
# 15  King Yudhisthira, the son of Kunti, the son of...
# 16  The sound of the sons of Dhṛtarāṣṭra tore the ...
# 17  Seeing the sons of the sons of Kapi who was st...
# 18  Arjuna said: O infallible one, please place my...
# 19  I am looking for those who assembled here in t...
# 20  Sanjaya said: Thus addressed by Gudakesha, O d...
# 21  O son of Pṛthā, please see these assembled by ...
# 22  There he saw the fathers and grandfathers the ...
# 23  Overcome with mercifulness Kaunteya looked at ...
# 24  Arjuna said: O Kṛṣṇa, when I saw this relative...
# 25  My body is trembling and my hair is thrilled a...
# 26  O Keśava, I cannot be able to stand in the sky...
# 27  O Kṛṣṇa, I do not see any good in killing my r...
# 28  O Govinda, what is the use of our kingdom or p...
# 29  They are the only ones who have taken refuge i...
# 30  Although these men are overwhelmed with greed ...
# 31  The eternal religious duties of a family are d...
# 32  O Kṛṣṇa, because of the influence of irreligio...
# 33  The mixture of the mixture of the family kills...
# 34  These are the defects of these defects of the ...
# 35  O Lord of the worlds, we have heard that the r...
# 36  Oh how a great sin we have decided to kill our...
# 37  If the sons of Dhṛtarāṣṭra kill me in battle w...
# 38  Having spoken thus to him Arjuna threw his arr...

# %%
list_slokas_chap2 = [str(x) for x in range(1, 41)]
list_slokas_chap2.extend(['42-43'])
list_slokas_chap2.extend([str(x) for x in range(44, 72)])

sloks_chap2 = get_chapter_slokas(2, list_slokas_chap2)

chap2_df = pd.DataFrame({'chapter_no': 2, 'slokas_no': list(sloks_chap2.keys()), 'slokas': list(sloks_chap2.values())})

slokas_df = pd.concat([slokas_df, chap2_df], ignore_index=True)

translate_slokas(slokas_df)

print(slokas_df)
# Out:
#      chapter_no slokas_no                                             slokas  \
# 0             1         1  धृतराष्ट्र उवाचधर्मक्षेत्रे कुरुक्षेत्रे समवेत...
# 1             1         2  सञ्जय उवाचदृष्ट्वा तु पाण्डवानीकं व्यूढं दुर्य...
# 2             1         3  पश्यैतां पाण्डुपुत्राणामाचार्य महतीं चमूम् ।व्...
# 3             1         4  अत्र श‍ूरा महेष्वासा भीमार्जुनसमा युधि ।युयुधा...
# 4             1         5  धृष्टकेतुश्चेकितानः काशिराजश्च वीर्यवान् ।पुरु...
# ..          ...       ...                                                ...
# 103           2        67  इन्द्रियाणां हि चरतां यन्मनोऽनुविधीयते ।तदस्य ...
# 104           2        68  तस्माद्यस्य महाबाहो निगृहीतानि सर्वशः ।इन्द्रि...
# 105           2        69  या निशा सर्वभूतानां तस्यां जागर्ति संयमी ।यस्य...
# 106           2        70  आपूर्यमाणमचलप्रतिष्ठंसमुद्रमापः प्रविशन्ति यद्...
# 107           2        71  विहाय कामान्यः सर्वान्पुमांश्चरति निःस्पृहः ।न...
#
#                                          slokas_google
# 0    Dhṛtarāṣṭra said: O Sanjaya, what did the Pāṇḍ...
# 1    Sanjaya saw the army of the Pāṇḍavas arranged ...
# 2    O teacher look at this great army of the sons ...
# 3    Here the great archer Bhīma and Arjuna are equ...
# 4    Dhrishtaketu Chekitana the mighty king of Kāśī...
# ..                                                 ...
# 103  When the mind is moving about in the senses, t...
# 104  Therefore, O mighty-armed one, whose intellige...
# 105  The night in which all living entities are awa...
# 106  Just as the waters of the ocean enter into the...
# 107  A man who gives up all his desires moves about...
#
# [108 rows x 4 columns]

# %%
output_csv_filename = "slokas_google.csv"

# Filter the DataFrame to select only the rows where "chapter_no" is 1 and save selected columns to a CSV file
slokas_df[slokas_df['chapter_no'] == 1][['slokas_no', 'english_translation']].to_csv(output_csv_filename, index=False)

print(f"Chapter 1 slokas have been saved to {output_csv_filename}")
